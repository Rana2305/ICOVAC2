# %%
import pandas as pd
import scipy
import pyreadstat
import pyshs
import matplotlib.pyplot as plt
import seaborn as sns
import prince
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
dict_data = pd.read_excel(r"C:\Users\rana_\OneDrive\Bureau\inserm\travaux\ICOVAC2\transfer_8001089_files_a0cee13b\ICOVAC_V2_20231221\ICOVAC_V2_CAWI_20231221+poids.xlsx",
                    sheet_name=['codes', 'labels'])

# %%
codes_data = dict_data .get('codes')
labels_data = dict_data.get('labels')

# %%
labels_data
# Out:
#       CaseId    poids_init  poids_redresses  poids_redresses_stand  \
# 0          9  23694.276164     24731.997916               1.043796
# 1         10  23694.276164     23612.557779               0.996551
# 2         11  23694.276164     23167.075561               0.977750
# 3         12  23694.276164     23740.275946               1.001941
# 4         13  23694.276164     24514.791844               1.034629
# ...      ...           ...              ...                    ...
# 2164    5941  23694.276164     23821.680213               1.005377
# 2165    5947  23694.276164     23570.115118               0.994760
# 2166    6045  23694.276164     25415.071491               1.072625
# 2167    6046  23694.276164     25113.049226               1.059878
# 2168    6047  23694.276164     24260.602513               1.023901
#
#                   COMPLET   Q01  Q01_R0  Q01_R1        Q02  \
# 0     Section 4 complétée  1955      68   65-74  Une femme
# ...

# %%
list_indeps = ['Q02', 'Q07', 'Q01_R1', 'Q05_R0',  'Diplome', 'Q12', 'Q09', 'Q05_B', 'Q05_A', 'Q11', 'Q14',  'Q15_A', 'Q16_A'
               , 'Q17_A', 'Q18_A', 'Ty_hes_vaccinale1', 'Q19_A', 'Q20', 'Q21', 'Q33_A', 'Q33_B', 'Q33_C', 'Q33_D', 'Q33_E'
              , 'Q33_F', 'Q33_G', 'Q33_H', 'Q33_I', 'Q33_J', 'Q33_K', 'Q33_L', 'Q33_M', 'Q33_N', 'Q33_O', 'Q33_P', 'Q33_Q'
              , 'Q34_A', 'Q34_B', 'Q34_C', 'Q34_D', 'Q34_E', 'Q34_F', 'Q34_G', 'Q34_H', 'Q34_I', 'Q34_J', 'Q34_K', 'Q34_L'
              , 'Q34_M', 'Q35_A', 'Q35_B', 'Q35_C', 'Q35_D', 'Q35_E', 'Q35_F', 'Q35_G', 'Q35_H', 'Q35_I', 'Q35_J', 'Q35_K'
              , 'Q36_A', 'Q36_B', 'Q36_C', 'Q38_M1', 'Q38_M2', 'Q38_M3', 'Reseaux_sociaux_placement', 'Q39', 'Q40', 'Q41'
              , 'competpol_score', 'compet_pol_3', 'Q42_A', 'Q42_A_cat', 'Q43', 'Q45_A', 'Q45_B', 'Q45_C', 'Q45_D', 'Q45_E'
              , 'Q45_F', 'Q45_G', 'Q45_H', 'Q45_I', 'Q45_J', 'Q45_K', 'Q45_L', 'Q45_M', 'Q45_N', 'Q46', 'Q47']

questions_variables = {'Q02' : "Êtes-vous :", 'Q07' : "En prenant en compte tous les types de revenus que touchent les membres de votre foyer, quel est actuellement le montant mensuel net des ressources de l’ensemble votre ménage ?"
                       , 'Q01_R1' : "Tranche d'âge", 'Q05_R0' : "Catégorie socio-professionnelle",  'Diplome' : "À ce jour, le plus haut diplôme que vous possédez est… ?"
                      , 'Q12': "Êtes-vous...", 'Q09' : "Avez-vous des enfants à votre charge ?", 'Q05_B' : "Quelle est votre profession principale ou, si vous ne travaillez pas actuellement, la dernière profession principale que vous avez exercée ?"
                      , 'Q05_A': "Actuellement, quelle est votre situation ?", 'Q11' : "Dans quels pays êtes-vous né(e)?", 'Q14' : "Êtes-vous très, plutôt, plutôt pas ou pas du tout favorable aux vaccinations en général ?"
                      ,  'Q15_A' : "Êtes-vous favorable au vaccin contre les papillomavirus humains (HPV) ?", 'Q16_A' : "Êtes-vous favorable au vaccin contre la rougeole ?"
                      , 'Q17_A' : "Êtes-vous favorable au vaccin contre l’hépatite B ?", 'Q18_A' : "Êtes-vous favorable au vaccin contre la grippe ?"
                      , 'Ty_hes_vaccinale1' : "Typologie hésitation vaccinale", 'Q19_A' : "Combien de doses de vaccins contre la COVID-19 avez-vous reçu ?"
                      , 'Q20' : "Au moment où vous vous êtes fait vacciner contre la COVID-19, est-ce que vous aviez encore des doutes ou des réticences concernant le vaccin que vous avez eu ?"
                      , 'Q21' : "Et aujourd’hui, est-ce que vous avez toujours des doutes ou des réticences concernant le vaccin que vous avez eu ?"
                      , 'Q33_A' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat intervient beaucoup trop dans la vie quotidienne des gens."
                      , 'Q33_B' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Parfois, le gouvernement doit légiférer pour empêcher les gens de faire les mauvais choix."
                      , 'Q33_C' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Ce n'est pas à l’Etat de protéger les gens contre eux-mêmes."
                      , 'Q33_D' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Le gouvernement devrait cesser de dire aux gens comment ils doivent vivre leur vie."
                      , 'Q33_E' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat devrait faire davantage pour promouvoir le bien commun, même si cela implique de limiter la liberté et les choix des individus."
                      , 'Q33_F' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat devrait poser des limites aux choses que les individus peuvent faire afin de préserver l’intérêt général."
                      , 'Q33_G' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Aujourd'hui, trop de gens attendent de la société qu'elle fasse pour eux des choses qu'ils devraient faire pour eux-mêmes." 
                      , 'Q33_H' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? C’est le devoir de la société de veiller à ce que les besoins fondamentaux de chacun soient satisfaits."
                      , 'Q33_I' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? C'est une erreur de demander à la société d'aider toutes les personnes qui sont dans le besoin."
                      , 'Q33_J' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Les gens devraient pouvoir compter sur l'aide de l’Etat lorsqu'ils en ont besoin."
                      , 'Q33_K' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? La société fonctionne mieux lorsqu'elle laisse les individus prendre la responsabilité de leur propre vie sans leur dire ce qu'ils doivent faire."
                      , 'Q33_L' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat fait trop de choses pour trop de gens. Nous devrions laisser les gens s'occuper d'eux-mêmes."
                      , 'Q33_M' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Si l’Etat passait moins de temps à essayer de résoudre tous les problèmes, les choses iraient bien mieux pour tout le monde"
                      , 'Q33_N' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Les personnes qui réussissent dans les affaires devraient avoir le droit de jouir de leur richesse comme bon leur semblent."
                      , 'Q33_O' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’économie de marché - et non pas l’intervention de l’Etat - est le meilleur moyen de fournir aux gens les choses dont ils ont besoin."
                      , 'Q33_P' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? La recherche du gain est la principale motivation pour travailler dur."
                      , 'Q33_Q' : "Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Les réglementations administratives sont presque toujours une perte de temps et d'argent pour tout le monde."
                      , 'Q34_A' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Nous sommes allés trop loin dans la promotion des droits des minorités dans ce pays."
                      , 'Q34_B' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? De nos jours, il semblerait qu'il y ait autant de discrimination vis-à-vis des Blancs que vis-à-vis des Noirs."
                      , 'Q34_C' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Notre société se porterait mieux si les richesses étaient plus équitablement réparties."
                      , 'Q34_D' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il faudrait réduire considérablement les inégalités entre les riches et les pauvres, entre les Blancs et les personnes de couleur, ainsi qu’entre les hommes et les femmes."
                      , 'Q34_E' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Les discriminations à l'encontre des minorités restent un problème très important dans notre société."
                      , 'Q34_F' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il semble que les noirs, les femmes, les homosexuels et les autres minorités ne veulent pas l'égalité des droits, mais des droits juste pour eux."
                      , 'Q34_G' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il semblerait que les délinquants et les assistés aient tous les droits, tandis que les français moyens doivent se serrer la ceinture."
                      , 'Q34_H' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il est dépassé et faux de penser que les valeurs et les visions du monde d'une certaine culture peuvent être meilleures que celles d’autres cultures."
                      , 'Q34_I' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Le mouvement pour les droits des femmes va trop loin."
                      , 'Q34_J' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Nous vivons dans une société sexiste qui est fondamentalement discriminante vis-à-vis des femmes."
                      , 'Q34_K' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Beaucoup de problèmes dans notre société actuelle viennent du déclin de la famille traditionnelle, dans laquelle les hommes travaillent et les femmes restent à la maison."
                      , 'Q34_L' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? La société dans son ensemble est devenue trop sensible et trop féminine."
                      , 'Q34_M' : "Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Les parents devraient encourager les jeunes garçons à être plus sensibles et moins brutaux."
                      , 'Q35_A' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Elles ont un coût pour nous personnellement."
                      , 'Q35_B' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Les individus devraient avoir davantage la responsabilité de subvenir à leurs propres besoins."
                      , 'Q35_C' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Les chômeurs devraient être obligés d’accepter tout emploi disponible ou bien perdre leur indemnité de chômage."
                      , 'Q35_D' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Les chômeurs devraient avoir le droit de refuser un emploi qui ne leur convient pas."
                      , 'Q35_E' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait qu’on respecte davantage l’autorité dans ce pays."
                      , 'Q35_F' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait davantage maintenir l’ordre dans ce pays."
                      , 'Q35_G' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait encourager davantage les efforts individuels dans ce pays."
                      , 'Q35_H' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait davantage garantir la liberté d’expression dans ce pays."
                      , 'Q35_I' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait augmenter la participation des citoyens aux décisions du gouvernement."
                      , 'Q35_J' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? L’État devrait avoir davantage la responsabilité d’assurer à chacun ses besoins."
                      , 'Q35_K' : "Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? L'Etat devrait faire davantage confiance aux entreprises et leur donner plus de liberté."
                      , 'Q36_A' : "Voici une dernière série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Je préfère faire confiance à la sagesse des personnes ordinaires qu’aux opinions des experts et intellectuels."
                      , 'Q36_B' : "Voici une dernière série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Lorsqu'il s'agit de questions vraiment importantes, les faits scientifiques ne sont pas d'une grande aide."
                      , 'Q36_C' : "Voici une dernière série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Pour comprendre des choses compliquées comme la science et la santé, l’aide des experts peut être vraiment utile pour les citoyens ordinaires."
                      , 'Q38_M1' : "Habituellement, pour vous informer, quel(s) moyen(s) utilisez-vous de préférence ? Premier moyen le plus important"
                      , 'Q38_M2' : "Habituellement, pour vous informer, quel(s) moyen(s) utilisez-vous de préférence ? Deuxième moyen le plus important"
                      , 'Q38_M3' : "Habituellement, pour vous informer, quel(s) moyen(s) utilisez-vous de préférence ? Troisième moyen le plus important"
                      , 'Reseaux_sociaux_placement' : "Placement de réseaux sociaux dans les 3 premières sources d'information", 'Q39' : "Diriez-vous que vous vous intéressez à la politique ?"
                      , 'Q40' : "A quelle fréquence suivez-vous l’actualité politique ?", 'Q41' : "A quelle fréquence participez-vous aux élections ?"
                      , 'competpol_score' : "Compétence politique score", 'compet_pol_3' : "Compétence politique score (3groupes)", 'Q42_A' : "De laquelle des formations politiques suivantes vous sentez-vous le plus proche ou disons le moins éloigné ?"
                      , 'Q42_A_cat' : "De laquelle des formations politiques suivantes vous sentez-vous le plus proche ou disons le moins éloigné ?"
                      , 'Q43' : "A quel point vous sentez-vous proche de ce parti ?", 'Q45_A' : "Avez-vous confiance ou pas confiance dans : La justice"
                      , 'Q45_B' : "Avez-vous confiance ou pas confiance dans : Les médias", 'Q45_C' : "Avez-vous confiance ou pas confiance dans : La police"
                      , 'Q45_D' : "Avez-vous confiance ou pas confiance dans : L’assemblée nationale", 'Q45_E' : "Avez-vous confiance ou pas confiance dans : Les maires"
                      , 'Q45_F' : "Avez-vous confiance ou pas confiance dans : La science", 'Q45_G' : "Avez-vous confiance ou pas confiance dans : Les grandes entreprises"
                      , 'Q45_H' : "Avez-vous confiance ou pas confiance dans : Les agences gouvernementales qui contrôlent les risques liés à la santé et à l'environnement", 'Q45_I' : "Avez-vous confiance ou pas confiance dans : Le gouvernement"
                      , 'Q45_J' : "Avez-vous confiance ou pas confiance dans : Les médecins", 'Q45_K' : "Avez-vous confiance ou pas confiance dans : Les industriels du médicament"
                      , 'Q45_L' : "Avez-vous confiance ou pas confiance dans : Les partis politiques", 'Q45_M' : "Avez-vous confiance ou pas confiance dans : L’armée"
                      , 'Q45_N' : "Avez-vous confiance ou pas confiance dans : Les scientifiques", 'Q46' : "D'une manière générale, avez-vous l'impression que la science apporte à l'homme plus de bien que de mal, plus de mal que de bien ou à peu près autant de bien que de mal ?"
                      , 'Q47' : "D’après vous, les connaissances actuelles permettent-elles de trancher le débat scientifique autour de l’efficacité de la chloroquine et de ses dérivés contre le COVID-19 ?"}

# %%
data = labels_data

# %%
# Variable 'Q02'
# Question : Êtes-vous :
data['Q02'].value_counts()
# Out:
# Q02
# Une femme    1151
# Un homme     1013
# Autre           5
# Name: count, dtype: int64

# %%
data['Q02'] = pd.Categorical(data['Q02'], 
                            categories=['Une femme', 'Un homme'
                                        , 'Autre'], 
                            ordered=True)

# %%
data['Q02'].value_counts()
# Out:
# Q02
# Une femme    1151
# Un homme     1013
# Autre           5
# Name: count, dtype: int64

# %%
# Variable 'Q01_R1'
# Question : Tranche d'âge
data['Q01_R1'].value_counts()
# Out:
# Q01_R1
# 50-64     536
# 35-49     512
# 25-34     317
# 65-74     313
# 75plus    270
# 18-24     221
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q01_R1'
data['Q01_R1'] = pd.Categorical(data['Q01_R1'], 
                            categories=['18-24'
                                        , '25-34'
                                        , '35-49'
                                       , '50-64'
                                       , '65-74'
                                       , '75plus'], 
                            ordered=True)

# %%
# Variable 'Q07'
# Question : En prenant en compte tous les types de revenus que touchent les membres de votre foyer, quel est actuellement le montant mensuel net des ressources de l’ensemble votre ménage ?
data['Q07'].value_counts()
# Out:
# Q07
# 2000 à 3000 euros                 509
# 3000 à 4000 euros                 411
# 4000 euros et plus                382
# 1500 à 2000 euros                 324
# Vous ne souhaitez pas répondre    205
# 1000 à 1500 euros                 192
# Moins de 1000 euros               146
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable'Q07'
data['Q07'] = pd.Categorical(data['Q07'], 
                            categories=['Moins de 1000 euros', '1000 à 1500 euros' ,'1500 à 2000 euros'
                                        ,'2000 à 3000 euros', '3000 à 4000 euros'
                                       , '4000 euros et plus', 'Vous ne souhaitez pas répondre'], 
                            ordered=True)

# %%
# Variable 'Q05_R0'
# Question : Catégorie socio-professionnelle
data['Q05_R0'].value_counts()
# Out:
# Q05_R0
# Retraités                                            721
# Employés                                             311
# Professions Intermédiaires                           310
# Autres personnes sans activité professionnelle       257
# Ouvriers                                             245
# Cadres ou professions intellectuelles supérieures    234
# Artisans, commerçants ou chefs d&apos;entreprise      76
# Agriculteurs                                          14
# #NULL!                                                 1
# Name: count, dtype: int64

# %%
# Variable 'Q06'
# Question : À ce jour, le plus haut diplôme que vous possédez est… ?
data['Q06'].value_counts()
# Out:
# Q06
# CAP, BEP, mention complémentaire, diplôme de la santé ou du travail social de niveau équivalent                        368
# Baccalauréat technologique ou professionnel                                                                            307
# BTS, DUT, DEUST ou diplôme équivalent                                                                                  288
# Baccalauréat général, brevet supérieur, capacité en droit, DAEU ou diplôme équivalent                                  222
# Diplôme de 2ème cycle universitaire (licence, L3, maîtrise, M1) ou diplôme équivalent (y/c CAPES)                      217
# BEPC, brevet des collèges, brevet élémentaire, 1ère partie du baccalauréat                                             200
# Diplôme de 3ème cycle universitaire (DES, DEA, DESS, Master, M2) y compris médecine, pharmacie, dentaire ou diplôme    145
# ...

# %%
data['Diplome'] = data['Q06'].apply(lambda x : x.replace("Aucun diplôme", "Aucun diplôme, CEP").
                                        replace("Certificat d’études primaires, diplôme de fin d’études obligatoires","Aucun diplôme, CEP").
                                        replace("BEPC, brevet des collèges, brevet élémentaire, 1ère partie du baccalauréat","Avant Bac").
                                        replace("CAP, BEP, mention complémentaire, diplôme de la santé ou du travail social de niveau équivalent","Avant Bac").
                                        replace("Brevet professionnel ou de technicien, brevet des métiers, BEA, BEI, BEC, BEH, BES ou diplôme équivalent", "Avant Bac").
                                        replace("Baccalauréat technologique ou professionnel","Bac techno pro" ).
                                        replace("Baccalauréat général, brevet supérieur, capacité en droit, DAEU ou diplôme équivalent", "Bac").
                                        replace("BTS, DUT, DEUST ou diplôme équivalent", "BTS DUT").
                                        replace("Diplôme de la santé et du travailleur social (infirmière, puéricultrice, éducateur...)", "Diplôme santé").
                                        replace("Diplôme de 2ème cycle universitaire (licence, L3, maîtrise, M1) ou diplôme équivalent (y/c CAPES)", "Licence").
                                        replace("Diplôme de 3ème cycle universitaire (DES, DEA, DESS, Master, M2) y compris médecine, pharmacie, dentaire ou diplôme", "Master ou plus").
                                        replace("Diplôme d’une grande école (ingénieur, commerce...) ou diplôme équivalent", "Master ou plus").
                                        replace("Diplôme de 1er cycle universitaire (DEUG, L1, L2) ou diplôme équivalent", "Licence").
                                        replace("Doctorat de 3ème cycle universitaire", "Master ou plus")
                                        )

# %%
#changer l'order des categories de la variable 'Diplome'
data['Diplome'] = pd.Categorical(data['Diplome'], 
                            categories=['Aucun diplôme, CEP', 'Avant Bac' ,'Bac techno pro'
                                        ,'Bac', 'BTS DUT', 'Diplôme santé'
                                       , 'Licence', 'Master ou plus'], 
                            ordered=True)

# %%
# Variable 'Q12'
# Question : Êtes-vous...
data['Q12'].value_counts()
# Out:
# Q12
# Catholique                        1074
# Sans religion                      837
# Vous ne souhaitez pas répondre      97
# Musulman                            65
# Protestant ou évangélique           55
# Autre religion                      31
# Juif                                10
# Name: count, dtype: int64

# %%
# Variable 'Q09'
# Question : Avez-vous des enfants à votre charge ?
data['Q09'].value_counts()
# Out:
# Q09
# Non    1508
# Oui     661
# Name: count, dtype: int64

# %%
# Variable 'Q05_B'
# Question : Quelle est votre profession principale ou, si vous ne travaillez pas actuellement, la dernière profession principale que vous avez exercée ?
data['Q05_B'].value_counts()
# Out:
# Q05_B
# #NULL!                                                                                                                     212
# Cadres d&apos;entreprise (ex : administratifs et commerciaux)                                                              168
# Employés administratifs d&apos;entreprise (ex : standardistes, dactylos, secrétaires, hôtesses de l&apos;air,...)          151
# Professions intermédiaires de la santé et du travail social                                                                125
# Employés civils et agents de service de la fonction publique                                                               119
# Professions intermédiaires administratives et commerciales des entreprises                                                 118
# Ouvriers qualifiés de type industriel                                                                                      116
# ...

# %%
# Variable 'Q05_A'
# Question: Actuellement, quelle est votre situation ?
data['Q05_A'].value_counts()
# Out:
# Q05_A
# Vous exercez une activité professionnelle (actifs, apprentis, stagiaires)          1024
# Vous êtes à la retraite ou en pré-retraite                                          721
# Vous êtes collégien, lycéen ou étudiant                                             184
# Vous êtes chômeur ayant déjà travaillé                                               88
# Vous êtes homme ou femme au foyer                                                    69
# Vous êtes dans une autre situation (invalide, sans activité professionnelle...)      55
# Vous êtes à la recherche d&apos;un premier emploi                                    28
# Name: count, dtype: int64

# %%
# Variable 'Q11'
# Question: Dans quels pays êtes-vous né(e)?
data['Q11'].value_counts()
# Out:
# Q11
# France                          2085
# Autre pays (préciser lequel)      84
# Name: count, dtype: int64

# %%
# Variable 'Q14'
# Question: Êtes-vous très, plutôt, plutôt pas ou pas du tout favorable aux vaccinations en général ?
data['Q14'].value_counts()
# Out:
# Q14
# Plutôt favorable         1205
# Très favorable            605
# Plutôt pas favorable      222
# Pas du tout favorable      90
# Vous ne savez pas          47
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q14'
data['Q14'] = pd.Categorical(data['Q14'], 
                            categories=['Pas du tout favorable', 'Plutôt pas favorable' ,'Plutôt favorable'
                                        ,'Très favorable', 'Vous ne savez pas'], 
                            ordered=True)

# %%
# Variable 'Q15_A'
# Question: Êtes-vous favorable au vaccin contre les papillomavirus humains (HPV) ?
data['Q15_A'].value_counts()
# Out:
# Q15_A
# Oui, plutôt          863
# Oui, tout à fait     758
# Vous ne savez pas    217
# Non, plutôt pas      212
# Non, pas du tout     119
# Name: count, dtype: int64

# %%
# Variable 'Q16_A'
# Question: Êtes-vous favorable au vaccin contre la rougeole ?
data['Q16_A'].value_counts()
# Out:
# Q16_A
# Oui, tout à fait     985
# Oui, plutôt          924
# Non, plutôt pas      131
# Vous ne savez pas     77
# Non, pas du tout      52
# Name: count, dtype: int64

# %%
# Variable 'Q17_A'
# Question: Êtes-vous favorable au vaccin contre l’hépatite B ?
data['Q17_A'].value_counts()
# Out:
# Q17_A
# Oui, plutôt          919
# Oui, tout à fait     761
# Non, plutôt pas      230
# Vous ne savez pas    156
# Non, pas du tout     103
# Name: count, dtype: int64

# %%
# Variable 'Q18_A'
# Question: Êtes-vous favorable au vaccin contre la grippe ?
data['Q18_A'].value_counts()
# Out:
# Q18_A
# Oui, tout à fait     743
# Oui, plutôt          738
# Non, plutôt pas      416
# Non, pas du tout     197
# Vous ne savez pas     75
# Name: count, dtype: int64

# %%
data[['Q15_A', 'Q16_A', 'Q17_A', 'Q18_A']] = data[['Q15_A', 'Q16_A', 'Q17_A', 'Q18_A']].astype('category')

# %%
Vaccins_Q = ['Q15_A', 'Q16_A', 'Q17_A', 'Q18_A']
for i in data[Vaccins_Q].columns:
    data[i] = pd.Categorical(data[i], 
                            categories=['Non, pas du tout', 'Non, plutôt pas'
                                        ,'Oui, plutôt', 'Oui, tout à fait'
                                       , 'Vous ne savez pas'] 
                                        , ordered=True)

# %%
# Typologie hésitation vaccinale pour touts les vaccins:

# variable 'Q14' : Question : Êtes-vous très, plutôt, plutôt pas ou pas du tout favorable aux vaccinations en général ?
# variable 'Q15_A' : Question : Êtes-vous favorable au vaccin contre les papillomavirus humains (HPV) ?
# variable 'Q16_A' : Question : Êtes-vous favorable au vaccin contre la rougeole ?
# variable 'Q17_A' : Question : Êtes-vous favorable au vaccin contre l’hépatite B ?
# variable 'Q18_A' : Question : Êtes-vous favorable au vaccin contre la grippe ?

# %%
data_vaccin = data[['Q14', 'Q15_A', 'Q16_A', 'Q17_A', 'Q18_A']]

# %%
# définir une fonction pour recoder la variable 'Q14':
def vaccinaltyQ14(x):
    if x == 'Plutôt favorable':
        return 'Favorable'
    if x == 'Très favorable':
        return 'Favorable'
    if x == 'Plutôt pas favorable':
        return 'Défavorable'
    if x == 'Pas du tout favorable':
        return 'Défavorable'
    if x == 'Vous ne savez pas':
        return 'Je ne sais pas'

# %%
data_vaccin['Q14_cat']= data_vaccin['Q14'].apply(lambda x : vaccinaltyQ14(x))
# Out:
# <ipython-input-286-64082ce5ee6d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_vaccin['Q14_cat']= data_vaccin['Q14'].apply(lambda x : vaccinaltyQ14(x))

# %%
data_vaccin['Q14_cat'].value_counts()
# Out:
# Q14_cat
# Favorable         1810
# Défavorable        312
# Je ne sais pas      47
# Name: count, dtype: int64

# %%
# définir une fonction pour recoder la variable 'Q15_A':
def vaccinaltyQ15_A(x):
    if x == 'Oui, plutôt':
        return 'Favorable'
    if x == 'Oui, tout à fait':
        return 'Favorable'
    if x == 'Non, plutôt pas':
        return 'Défavorable'
    if x == 'Non, pas du tout':
        return 'Défavorable'
    if x == 'Vous ne savez pas':
        return 'Je ne sais pas'

# %%
data_vaccin['Q15_A_cat']= data_vaccin['Q15_A'].apply(lambda x : vaccinaltyQ15_A(x))
data_vaccin['Q16_A_cat']= data_vaccin['Q16_A'].apply(lambda x : vaccinaltyQ15_A(x))
data_vaccin['Q17_A_cat']= data_vaccin['Q17_A'].apply(lambda x : vaccinaltyQ15_A(x))
data_vaccin['Q18_A_cat']= data_vaccin['Q18_A'].apply(lambda x : vaccinaltyQ15_A(x))
# Out:
# <ipython-input-289-765eb74b4760>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_vaccin['Q15_A_cat']= data_vaccin['Q15_A'].apply(lambda x : vaccinaltyQ15_A(x))
# <ipython-input-289-765eb74b4760>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_vaccin['Q16_A_cat']= data_vaccin['Q16_A'].apply(lambda x : vaccinaltyQ15_A(x))
# <ipython-input-289-765eb74b4760>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# creer une colonne typologie d'hésitation vaccinale en 3 groupes:
# List of conditions
conditions = [
     (data_vaccin['Q14_cat'] == 'Favorable') &  (data_vaccin['Q15_A_cat'] == 'Favorable') & 
     (data_vaccin['Q16_A_cat'] == 'Favorable') & (data_vaccin['Q17_A_cat'] == 'Favorable') &
     (data_vaccin['Q18_A_cat'] == 'Favorable')
    ,(data_vaccin['Q14_cat'] == 'Favorable') & ((data_vaccin['Q15_A_cat'] != 'Favorable')| 
     (data_vaccin['Q16_A_cat'] != 'Favorable') | (data_vaccin['Q17_A_cat'] != 'Favorable')|
     (data_vaccin['Q18_A_cat'] != 'Favorable'))
    ,(data_vaccin['Q14_cat'] == 'Défavorable') | (data_vaccin['Q14_cat'] == 'Je ne sais pas')
    
   
]# List of values to return
choices  = [
      "Non-hesitan"
    , "Pro-vaccination mais sélectivement hésitant"
    , "Défavorable à la vaccination en général"
]# create a new column in the DF based on the conditions
data_vaccin["Ty_hes_vaccinale1"] = np.select(conditions, choices)
# Out:
# <ipython-input-290-1e132ebb4d4d>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_vaccin["Ty_hes_vaccinale1"] = np.select(conditions, choices)

# %%
data_vaccin["Ty_hes_vaccinale1"].value_counts()
# Out:
# Ty_hes_vaccinale1
# Non-hesitan                                      1101
# Pro-vaccination mais sélectivement hésitant     709
# Défavorable à la vaccination en général           359
# Name: count, dtype: int64

# %%
data1 = pd.concat([data, data_vaccin["Ty_hes_vaccinale1"]], axis = 1)

# %%
data1
# Out:
#       CaseId    poids_init  poids_redresses  poids_redresses_stand  \
# 0          9  23694.276164     24731.997916               1.043796
# 1         10  23694.276164     23612.557779               0.996551
# 2         11  23694.276164     23167.075561               0.977750
# 3         12  23694.276164     23740.275946               1.001941
# 4         13  23694.276164     24514.791844               1.034629
# ...      ...           ...              ...                    ...
# 2164    5941  23694.276164     23821.680213               1.005377
# 2165    5947  23694.276164     23570.115118               0.994760
# 2166    6045  23694.276164     25415.071491               1.072625
# 2167    6046  23694.276164     25113.049226               1.059878
# 2168    6047  23694.276164     24260.602513               1.023901
#
#                   COMPLET   Q01  Q01_R0  Q01_R1        Q02  \
# 0     Section 4 complétée  1955      68   65-74  Une femme
# ...

# %%
#changer l'order des categories de la variable 'Ty_hes_vaccinale1'
data1['Ty_hes_vaccinale1'] = pd.Categorical(data1['Ty_hes_vaccinale1'], 
                            categories=['Défavorable à la vaccination en général'
                                        , 'Pro-vaccination mais sélectivement hésitant'
                                        , 'Non-hesitan'], 
                            ordered=True)

# %%
# Variable 'Q19_A'
# Question: Combien de doses de vaccins contre la COVID-19 avez-vous reçu ?
data1['Q19_A'].value_counts()
# Out:
# Q19_A
# 3            804
# 2            521
# Plus de 4    271
# 4            262
# Aucune       249
# 1             62
# Name: count, dtype: int64

# %%
data1['Q19_A'] = data1['Q19_A'].astype('category')
#changer l'order des categories de la variable 'Q25_A'
data1['Q19_A'] = pd.Categorical(data1['Q19_A'], 
                        categories=["Aucune", "1", "2", "3", "4"
                                    , "Plus de 4"], 
                            ordered=True)

# %%
# Variable 'Q20'
# Question: Au moment où vous vous êtes fait vacciner contre la COVID-19, est-ce que vous aviez encore des doutes ou des réticences concernant le vaccin que vous avez eu ?
data1['Q20'].value_counts()
# Out:
# Q20
# Un peu                            580
# Pas du tout                       467
# Beaucoup                          450
# Pas vraiment                      388
# #NULL!                            249
# Vous ne savez pas                  28
# Vous ne souhaitez pas répondre      7
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q20'
data1['Q20'] = pd.Categorical(data1['Q20'], 
                        categories=["Pas du tout", "Pas vraiment", "Un peu", "Beaucoup"
                                    , "Vous ne savez pas"
                                    , "Vous ne souhaitez pas répondre" 
                                    , "#NULL!"], 
                            ordered=True)

# %%
# Variable 'Q21'
# Question: Et aujourd’hui, est-ce que vous avez toujours des doutes ou des réticences concernant le vaccin que vous avez eu ?
data1['Q21'].value_counts()
# Out:
# Q21
# Pas du tout                       600
# Un peu                            492
# Beaucoup                          410
# Pas vraiment                      372
# #NULL!                            249
# Vous ne savez pas                  39
# Vous ne souhaitez pas répondre      7
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q21'
data1['Q21'] = pd.Categorical(data1['Q21'], 
                        categories=["Pas du tout", "Pas vraiment", "Un peu", "Beaucoup"
                                    , "Vous ne savez pas"
                                    , "Vous ne souhaitez pas répondre" 
                                    , "#NULL!"], 
                            ordered=True)

# %%
# Variable 'Q33_A'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat intervient beaucoup trop dans la vie quotidienne des gens
data1['Q33_A'].value_counts()
# Out:
# Q33_A
# Plutôt d’accord         729
# Plutôt pas d’accord     497
# Tout à fait d’accord    333
# D’accord                293
# Pas d’accord            193
# Pas du tout d’accord     83
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_B'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Parfois, le gouvernement doit légiférer pour empêcher les gens de faire les mauvais choix.
data1['Q33_B'].value_counts()
# Out:
# Q33_B
# Plutôt d’accord         847
# Plutôt pas d’accord     513
# D’accord                302
# Pas d’accord            195
# Tout à fait d’accord    154
# Pas du tout d’accord    117
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_C'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Ce n'est pas à l’Etat de protéger les gens contre eux-mêmes.
data1['Q33_C'].value_counts()
# Out:
# Q33_C
# Plutôt d’accord         707
# Plutôt pas d’accord     480
# D’accord                292
# Tout à fait d’accord    272
# Pas d’accord            224
# Pas du tout d’accord    153
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_D'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Le gouvernement devrait cesser de dire aux gens comment ils doivent vivre leur vie.
data1['Q33_D'].value_counts()
# Out:
# Q33_D
# Plutôt d’accord         802
# Tout à fait d’accord    517
# D’accord                356
# Plutôt pas d’accord     291
# Pas d’accord            110
# Pas du tout d’accord     52
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_E'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat devrait faire davantage pour promouvoir le bien commun, même si cela implique de limiter la liberté et les choix des individus.
data1['Q33_E'].value_counts()
# Out:
# Q33_E
# Plutôt pas d’accord     633
# Plutôt d’accord         632
# Pas d’accord            278
# D’accord                245
# Pas du tout d’accord    226
# Tout à fait d’accord    114
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_F'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat devrait poser des limites aux choses que les individus peuvent faire afin de préserver l’intérêt général.
data1['Q33_F'].value_counts()
# Out:
# Q33_F
# Plutôt d’accord         857
# Plutôt pas d’accord     405
# D’accord                347
# Tout à fait d’accord    247
# Pas d’accord            151
# Pas du tout d’accord    121
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_G'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Aujourd'hui, trop de gens attendent de la société qu'elle fasse pour eux des choses qu'ils devraient faire pour eux-mêmes.
data1['Q33_G'].value_counts()
# Out:
# Q33_G
# Plutôt d’accord         694
# Tout à fait d’accord    613
# D’accord                401
# Plutôt pas d’accord     233
# Pas d’accord            125
# Pas du tout d’accord     62
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_H'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? C’est le devoir de la société de veiller à ce que les besoins fondamentaux de chacun soient satisfaits.
data1['Q33_H'].value_counts()
# Out:
# Q33_H
# Plutôt d’accord         919
# D’accord                382
# Plutôt pas d’accord     362
# Tout à fait d’accord    299
# Pas d’accord             94
# Pas du tout d’accord     72
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_I'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? C'est une erreur de demander à la société d'aider toutes les personnes qui sont dans le besoin.
data1['Q33_I'].value_counts()
# Out:
# Q33_I
# Plutôt d’accord         568
# Plutôt pas d’accord     535
# Pas d’accord            267
# Tout à fait d’accord    267
# D’accord                248
# Pas du tout d’accord    243
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_J'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Les gens devraient pouvoir compter sur l'aide de l’Etat lorsqu'ils en ont besoin.
data1['Q33_J'].value_counts()
# Out:
# Q33_J
# Plutôt d’accord         886
# Plutôt pas d’accord     361
# D’accord                331
# Tout à fait d’accord    321
# Pas d’accord            145
# Pas du tout d’accord     84
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_K'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? La société fonctionne mieux lorsqu'elle laisse les individus prendre la responsabilité de leur propre vie sans leur dire ce qu'ils doivent faire.
data1['Q33_K'].value_counts()
# Out:
# Q33_K
# Plutôt d’accord         800
# Plutôt pas d’accord     507
# D’accord                303
# Tout à fait d’accord    252
# Pas d’accord            164
# Pas du tout d’accord    102
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_L'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’Etat fait trop de choses pour trop de gens. Nous devrions laisser les gens s'occuper d'eux-mêmes.
data1['Q33_L'].value_counts()
# Out:
# Q33_L
# Plutôt d’accord         727
# Plutôt pas d’accord     500
# D’accord                267
# Tout à fait d’accord    262
# Pas d’accord            225
# Pas du tout d’accord    147
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_M'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Si l’Etat passait moins de temps à essayer de résoudre tous les problèmes, les choses iraient bien mieux pour tout le monde.
data1['Q33_M'].value_counts()
# Out:
# Q33_M
# Plutôt d’accord         641
# Plutôt pas d’accord     572
# Pas d’accord            258
# D’accord                235
# Tout à fait d’accord    235
# Pas du tout d’accord    187
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_N'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Les personnes qui réussissent dans les affaires devraient avoir le droit de jouir de leur richesse comme bon leur semblent.
data1['Q33_N'].value_counts()
# Out:
# Q33_N
# Plutôt d’accord         833
# Tout à fait d’accord    362
# D’accord                353
# Plutôt pas d’accord     330
# Pas d’accord            152
# Pas du tout d’accord     98
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_O'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? L’économie de marché - et non pas l’intervention de l’Etat - est le meilleur moyen de fournir aux gens les choses dont ils ont besoin.
data1['Q33_O'].value_counts()
# Out:
# Q33_O
# Plutôt d’accord         851
# Plutôt pas d’accord     534
# D’accord                270
# Pas d’accord            194
# Pas du tout d’accord    149
# Tout à fait d’accord    130
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_P'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? La recherche du gain est la principale motivation pour travailler dur.
data1['Q33_P'].value_counts()
# Out:
# Q33_P
# Plutôt d’accord         730
# Plutôt pas d’accord     440
# D’accord                368
# Tout à fait d’accord    295
# Pas d’accord            183
# Pas du tout d’accord    112
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q33_Q'
# Question: Voici une première série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas d’accord ou pas du  tout d’accord avec chacune d’entre elles ? Les réglementations administratives sont presque toujours une perte de temps et d'argent pour tout le monde.
data1['Q33_Q'].value_counts()
# Out:
# Q33_Q
# Plutôt d’accord         750
# Plutôt pas d’accord     470
# D’accord                319
# Tout à fait d’accord    298
# Pas d’accord            203
# Pas du tout d’accord     88
# #NULL!                   41
# Name: count, dtype: int64

# %%
# Variable 'Q34_A'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Nous sommes allés trop loin dans la promotion des droits des minorités dans ce pays.
data1['Q34_A'].value_counts()
# Out:
# Q34_A
# Plutôt d’accord         538
# Plutôt pas d’accord     494
# Tout à fait d’accord    355
# D’accord                269
# Pas d’accord            222
# Pas du tout d’accord    221
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_B'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? De nos jours, il semblerait qu'il y ait autant de discrimination vis-à-vis des Blancs que vis-à-vis des Noirs.
data1['Q34_B'].value_counts()
# Out:
# Q34_B
# Plutôt d’accord         593
# Tout à fait d’accord    426
# Plutôt pas d’accord     405
# D’accord                278
# Pas d’accord            201
# Pas du tout d’accord    196
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_C'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Notre société se porterait mieux si les richesses étaient plus équitablement réparties.
data1['Q34_C'].value_counts()
# Out:
# Q34_C
# Plutôt d’accord         721
# Tout à fait d’accord    550
# D’accord                327
# Plutôt pas d’accord     313
# Pas d’accord            104
# Pas du tout d’accord     84
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_D'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il faudrait réduire considérablement les inégalités entre les riches et les pauvres, entre les Blancs et les personnes de couleur, ainsi qu’entre les hommes et les femmes.
data1['Q34_D'].value_counts()
# Out:
# Q34_D
# Plutôt d’accord         732
# Tout à fait d’accord    551
# D’accord                364
# Plutôt pas d’accord     268
# Pas d’accord             94
# Pas du tout d’accord     90
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_E'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Les discriminations à l'encontre des minorités restent un problème très important dans notre société.
data1['Q34_E'].value_counts()
# Out:
# Q34_E
# Plutôt d’accord         773
# D’accord                384
# Tout à fait d’accord    384
# Plutôt pas d’accord     339
# Pas d’accord            125
# Pas du tout d’accord     94
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_F'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il semble que les noirs, les femmes, les homosexuels et les autres minorités ne veulent pas l'égalité des droits, mais des droits juste pour eux.
data1['Q34_F'].value_counts()
# Out:
# Q34_F
# Plutôt pas d’accord     526
# Plutôt d’accord         500
# Pas du tout d’accord    332
# Pas d’accord            258
# Tout à fait d’accord    245
# D’accord                238
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_G'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il semblerait que les délinquants et les assistés aient tous les droits, tandis que les français moyens doivent se serrer la ceinture.
data1['Q34_G'].value_counts()
# Out:
# Q34_G
# Tout à fait d’accord    702
# Plutôt d’accord         493
# D’accord                308
# Plutôt pas d’accord     269
# Pas du tout d’accord    188
# Pas d’accord            139
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_H'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Il est dépassé et faux de penser que les valeurs et les visions du monde d'une certaine culture peuvent être meilleures que celles d’autres cultures.
data1['Q34_H'].value_counts()
# Out:
# Q34_H
# Plutôt d’accord         684
# Plutôt pas d’accord     403
# Tout à fait d’accord    381
# D’accord                374
# Pas d’accord            153
# Pas du tout d’accord    104
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_I'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Le mouvement pour les droits des femmes va trop loin.
data1['Q34_I'].value_counts()
# Out:
# Q34_I
# Plutôt pas d’accord     616
# Plutôt d’accord         415
# Pas du tout d’accord    351
# Pas d’accord            337
# D’accord                208
# Tout à fait d’accord    172
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_J'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Nous vivons dans une société sexiste qui est fondamentalement discriminante vis-à-vis des femmes.
data1['Q34_J'].value_counts()
# Out:
# Q34_J
# Plutôt d’accord         745
# Plutôt pas d’accord     495
# Tout à fait d’accord    306
# D’accord                300
# Pas d’accord            164
# Pas du tout d’accord     89
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_K'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Beaucoup de problèmes dans notre société actuelle viennent du déclin de la famille traditionnelle, dans laquelle les hommes travaillent et les femmes restent à la maison.
data1['Q34_K'].value_counts()
# Out:
# Q34_K
# Plutôt pas d’accord     513
# Pas du tout d’accord    468
# Plutôt d’accord         377
# Pas d’accord            298
# D’accord                227
# Tout à fait d’accord    216
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_L'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? La société dans son ensemble est devenue trop sensible et trop féminine.
data1['Q34_L'].value_counts()
# Out:
# Q34_L
# Plutôt pas d’accord     679
# Plutôt d’accord         386
# Pas du tout d’accord    361
# Pas d’accord            335
# D’accord                197
# Tout à fait d’accord    141
# #NULL!                   70
# Name: count, dtype: int64

# %%
# Variable 'Q34_M'
# Question: Voici une deuxième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, d’accord, plutôt d’accord, plutôt pas d’accord, pas  d’accord ou pas du tout d’accord avec chacune d’entre elles ? Les parents devraient encourager les jeunes garçons à être plus sensibles et moins brutaux.
data1['Q34_M'].value_counts()
# Out:
# Q34_M
# Plutôt d’accord         740
# Tout à fait d’accord    598
# D’accord                427
# Plutôt pas d’accord     224
# #NULL!                   70
# Pas d’accord             64
# Pas du tout d’accord     46
# Name: count, dtype: int64

# %%
# Variable 'Q35_A'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Elles ont un coût pour nous personnellement. (Question pour Jeremy)
data1['Q35_A'].value_counts()
# Out:
# Q35_A
# Plutôt d’accord         908
# Plutôt pas d’accord     427
# D’accord                362
# Tout à fait d’accord    256
# Pas d’accord             87
# #NULL!                   86
# Pas du tout d’accord     43
# Name: count, dtype: int64

# %%
# Variable 'Q35_B'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Les individus devraient avoir davantage la responsabilité de subvenir à leurs propres besoins.
data1['Q35_B'].value_counts()
# Out:
# Q35_B
# Plutôt d’accord         906
# D’accord                492
# Tout à fait d’accord    368
# Plutôt pas d’accord     223
# #NULL!                   86
# Pas d’accord             65
# Pas du tout d’accord     29
# Name: count, dtype: int64

# %%
# Variable 'Q35_C'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Les chômeurs devraient être obligés d’accepter tout emploi disponible ou bien perdre leur indemnité de chômage.
data1['Q35_C'].value_counts()
# Out:
# Q35_C
# Plutôt pas d’accord     552
# Plutôt d’accord         479
# Tout à fait d’accord    335
# Pas du tout d’accord    277
# D’accord                224
# Pas d’accord            216
# #NULL!                   86
# Name: count, dtype: int64

# %%
# Variable 'Q35_D'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Les chômeurs devraient avoir le droit de refuser un emploi qui ne leur convient pas.
data1['Q35_D'].value_counts()
# Out:
# Q35_D
# Plutôt d’accord         703
# Plutôt pas d’accord     418
# D’accord                305
# Tout à fait d’accord    292
# Pas du tout d’accord    185
# Pas d’accord            180
# #NULL!                   86
# Name: count, dtype: int64

# %%
# Variable 'Q35_E'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait qu’on respecte davantage l’autorité dans ce pays.
data1['Q35_E'].value_counts()
# Out:
# Q35_E
# Tout à fait d’accord    840
# Plutôt d’accord         570
# D’accord                412
# Plutôt pas d’accord     166
# #NULL!                   86
# Pas d’accord             60
# Pas du tout d’accord     35
# Name: count, dtype: int64

# %%
# Variable 'Q35_F'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait davantage maintenir l’ordre dans ce pays.
data1['Q35_F'].value_counts()
# Out:
# Q35_F
# Tout à fait d’accord    858
# Plutôt d’accord         560
# D’accord                390
# Plutôt pas d’accord     172
# #NULL!                   86
# Pas d’accord             69
# Pas du tout d’accord     34
# Name: count, dtype: int64

# %%
# Variable 'Q35_G'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait encourager davantage les efforts individuels dans ce pays.
data1['Q35_G'].value_counts()
# Out:
# Q35_G
# Plutôt d’accord         810
# D’accord                542
# Tout à fait d’accord    525
# Plutôt pas d’accord     147
# #NULL!                   86
# Pas d’accord             38
# Pas du tout d’accord     21
# Name: count, dtype: int64

# %%
# Variable 'Q35_H'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait davantage garantir la liberté d’expression dans ce pays.
data1['Q35_H'].value_counts()
# Out:
# Q35_H
# Plutôt d’accord         734
# Tout à fait d’accord    479
# D’accord                436
# Plutôt pas d’accord     322
# #NULL!                   86
# Pas d’accord             76
# Pas du tout d’accord     36
# Name: count, dtype: int64

# %%
# Variable 'Q35_I'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Il faudrait augmenter la participation des citoyens aux décisions du gouvernement.
data1['Q35_I'].value_counts()
# Out:
# Q35_I
# Plutôt d’accord         729
# Tout à fait d’accord    525
# D’accord                473
# Plutôt pas d’accord     261
# #NULL!                   86
# Pas d’accord             59
# Pas du tout d’accord     36
# Name: count, dtype: int64

# %%
# Variable 'Q35_J'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? L’État devrait avoir davantage la responsabilité d’assurer à chacun ses besoins.
data1['Q35_J'].value_counts()
# Out:
# Q35_J
# Plutôt d’accord         742
# Plutôt pas d’accord     564
# D’accord                286
# Tout à fait d’accord    214
# Pas d’accord            182
# Pas du tout d’accord     95
# #NULL!                   86
# Name: count, dtype: int64

# %%
# Variable 'Q35_K'
# Question: Voici une troisième série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? L'Etat devrait faire davantage confiance aux entreprises et leur donner plus de liberté.
data1['Q35_K'].value_counts()
# Out:
# Q35_K
# Plutôt d’accord         828
# Plutôt pas d’accord     389
# D’accord                387
# Tout à fait d’accord    252
# Pas d’accord            135
# Pas du tout d’accord     92
# #NULL!                   86
# Name: count, dtype: int64

# %%
# Variable 'Q36_A'
# Question: Voici une dernière série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Je préfère faire confiance à la sagesse des personnes ordinaires qu’aux opinions des experts et intellectuels.
data1['Q36_A'].value_counts()
# Out:
# Q36_A
# Plutôt d’accord         665
# Plutôt pas d’accord     614
# D’accord                261
# Tout à fait d’accord    214
# Pas d’accord            205
# Pas du tout d’accord    120
# #NULL!                   90
# Name: count, dtype: int64

# %%
# Variable 'Q36_B'
# Question: Voici une dernière série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Lorsqu'il s'agit de questions vraiment importantes, les faits scientifiques ne sont pas d'une grande aide.
data1['Q36_B'].value_counts()
# Out:
# Q36_B
# Plutôt pas d’accord     679
# Plutôt d’accord         473
# Pas d’accord            372
# Pas du tout d’accord    272
# D’accord                181
# Tout à fait d’accord    102
# #NULL!                   90
# Name: count, dtype: int64

# %%
# Variable 'Q36_C'
# Question: Voici une dernière série de propositions sur lesquelles tout le monde n’est pas d’accord. Diriez-vous que vous êtes tout à fait d’accord, plutôt d’accord, plutôt pas d’accord ou pas du tout d’accord  avec chacune d’entre elles ? Pour comprendre des choses compliquées comme la science et la santé, l’aide des experts peut être vraiment utile pour les citoyens ordinaires.
data1['Q36_C'].value_counts()
# Out:
# Q36_C
# Plutôt d’accord         882
# D’accord                496
# Tout à fait d’accord    400
# Plutôt pas d’accord     183
# #NULL!                   90
# Pas d’accord             75
# Pas du tout d’accord     43
# Name: count, dtype: int64

# %%
Items33_34_35_36 = ['Q33_A', 'Q33_B', 'Q33_C', 'Q33_D', 'Q33_E', 'Q33_F', 'Q33_G', 'Q33_H', 'Q33_I', 'Q33_J', 'Q33_K', 'Q33_L'
                    , 'Q33_M', 'Q33_N', 'Q33_O', 'Q33_P', 'Q33_Q', 'Q34_A', 'Q34_B', 'Q34_C', 'Q34_D', 'Q34_E', 'Q34_F', 'Q34_G'
                    , 'Q34_H', 'Q34_I', 'Q34_J', 'Q34_K', 'Q34_L', 'Q34_M', 'Q35_A', 'Q35_B', 'Q35_C', 'Q35_D', 'Q35_E', 'Q35_F'
                    , 'Q35_G', 'Q35_H', 'Q35_I', 'Q35_J', 'Q35_K', 'Q36_A', 'Q36_B', 'Q36_C']

# %%
for i in data1[Items33_34_35_36].columns:
    data1[i] = pd.Categorical(data1[i], 
                            categories=['Pas du tout d’accord', 'Pas d’accord', 'Plutôt pas d’accord'
                                        ,'Plutôt d’accord', 'D’accord'
                                        , 'Tout à fait d’accord'
                                        , '#NULL!'] 
                                        , ordered=True)

# %%
# Variable 'Q38_M1'
# Question: Habituellement, pour vous informer, quel(s) moyen(s) utilisez-vous de préférence ? Premier moyen le plus important
data1['Q38_M1'].value_counts()
# Out:
# Q38_M1
# La télévision                                              1141
# La radio                                                    257
# Les sites de médias sur Internet ou leur compte Twitter     188
# La presse écrite imprimée                                   164
# Les réseaux sociaux (Facebook, Twitter, etc.)               135
# Les discussions avec vos proches                             97
# #NULL!                                                       97
# D’autres sites Internet                                      90
# Name: count, dtype: int64

# %%
# Variable 'Q38_M2'
# Question: Habituellement, pour vous informer, quel(s) moyen(s) utilisez-vous de préférence ? Deuxième moyen le plus important
data1['Q38_M2'].value_counts()
# Out:
# Q38_M2
# La radio                                                   490
# La télévision                                              325
# La presse écrite imprimée                                  277
# Les sites de médias sur Internet ou leur compte Twitter    265
# Les discussions avec vos proches                           236
# #NULL!                                                     209
# Les réseaux sociaux (Facebook, Twitter, etc.)              185
# D’autres sites Internet                                    182
# Name: count, dtype: int64

# %%
# Variable 'Q38_M3'
# Question: Habituellement, pour vous informer, quel(s) moyen(s) utilisez-vous de préférence ? Troisième moyen le plus important
data1['Q38_M3'].value_counts()
# Out:
# Q38_M3
# #NULL!                                                     503
# Les discussions avec vos proches                           446
# La radio                                                   234
# Les réseaux sociaux (Facebook, Twitter, etc.)              222
# La presse écrite imprimée                                  200
# D’autres sites Internet                                    198
# Les sites de médias sur Internet ou leur compte Twitter    190
# La télévision                                              176
# Name: count, dtype: int64

# %%
# creer une colonne de Reseaux sociaux placement en 4 groupes:
# List of conditions
conditions = [
     (data1['Q38_M1'] == 'Les réseaux sociaux (Facebook, Twitter, etc.)') & (data1['Q38_M2'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') & 
     (data1['Q38_M3'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)')
    ,(data1['Q38_M1'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') & (data1['Q38_M2'] == 'Les réseaux sociaux (Facebook, Twitter, etc.)') &
     (data1['Q38_M3'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') 
    ,(data1['Q38_M1'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') & (data1['Q38_M2'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') &
     (data1['Q38_M3'] == 'Les réseaux sociaux (Facebook, Twitter, etc.)')
    ,(data1['Q38_M1'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') & (data1['Q38_M2'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') &
     (data1['Q38_M3'] != 'Les réseaux sociaux (Facebook, Twitter, etc.)') 
   
]# List of values to return
choices  = [
      "Première source" 
    , "Deuxième source"
    , "Troisième source"
    , "Pas dans les 3 premières"
]# create a new column in the data based on the conditions
data1["Reseaux_sociaux_placement"] = np.select(conditions, choices)

# %%
data1["Reseaux_sociaux_placement"].value_counts()
# Out:
# Reseaux_sociaux_placement
# Pas dans les 3 premières    1627
# Troisième source             222
# Deuxième source              185
# Première source              135
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Reseaux_sociaux_placement'
data1['Reseaux_sociaux_placement'] = pd.Categorical(data1['Reseaux_sociaux_placement'], 
                            categories=['Pas dans les 3 premières', 'Première source', 'Deuxième source'
                                        , 'Troisième source'], 
                            ordered=True)

# %%
# Variable 'Q39'
# Question: Diriez-vous que vous vous intéressez à la politique ?
data1['Q39'].value_counts()
# Out:
# Q39
# Oui, un peu          883
# Non, pas vraiment    504
# Oui, beaucoup        408
# Non, pas du tout     276
# #NULL!                98
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable'Q39'
data1['Q39'] = pd.Categorical(data1['Q39'], 
                            categories=['Non, pas du tout', 'Non, pas vraiment'
                                        ,'Oui, un peu', 'Oui, beaucoup'
                                       , '#NULL!'], 
                            ordered=True)

# %%
# Variable 'Q40'
# Question: A quelle fréquence suivez-vous l’actualité politique ?
data1['Q40'].value_counts()
# Out:
# Q40
# Tous les jours ou presque      597
# Moins souvent                  458
# Plusieurs fois par semaine     450
# Une à deux fois par semaine    363
# Jamais                         202
# #NULL!                          99
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable'Q40'
data1['Q40'] = pd.Categorical(data1['Q40'], 
                            categories=['Jamais', 'Moins souvent'
                                        ,'Une à deux fois par semaine'
                                        , 'Plusieurs fois par semaine'
                                        , 'Tous les jours ou presque'
                                        , '#NULL!'], 
                            ordered=True)

# %%
# Variable 'Q41'
# Question: A quelle fréquence participez-vous aux élections ?
data1['Q41'].value_counts()
# Out:
# Q41
# Vous votez à toutes les élections        1224
# Vous votez à la plupart des élections     412
# Vous votez à certaines élections          200
# Vous ne votez pas                         129
# Vous votez rarement                       105
# #NULL!                                     99
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable'Q41'
data1['Q41'] = pd.Categorical(data1['Q41'], 
                            categories=['Vous ne votez pas', 'Vous votez rarement'
                                        ,'Vous votez à certaines élections'
                                        , 'Vous votez à la plupart des élections'
                                        , 'Vous votez à toutes les élections'
                                       , '#NULL!'], 
                            ordered=True)

# %%
# Compétence politique : Il s’agit d’une variable score produite à partir de 3 questions :
# Q44 : « Diriez-vous que vous vous intéressez à la politique ? Oui, beaucoup/Oui, un peu/Non, pas vraiment/Non, pas du tout »
# Q45 : « A quelle fréquence suivez-vous l’actualité politique ? Tous les jours ou presque/Plusieurs fois par semaine/Une à deux fois par semaine/Moins souvent/Jamais »
# Q46 : « A quelle fréquence participez-vous aux élections ?
# Vous votez à toutes les élections/Vous votez à la plupart des élections/Vous votez à certaines élections/Vous votez rarement/Vous ne votez pas »

# Les questions ont été recodées en numérique avec des scores allant de 0 (niveau minimal de compétence politique) à 4 (plus haut niveau).
# Nous avons ensuite réalisé une ACM et récupéré les coordonnés des individus sur le premier axe factoriel.

# %%
data_compet = data1[['Q39', 'Q40', 'Q41']]

# %%
# définir une fonction pour recoder la variable 'Q39':
def competpolitique_Q39(x):
    if x == 'Non, pas du tout' or x == '#NULL!':
        return 0
    if x == 'Non, pas vraiment':
        return 1
    if x == 'Oui, un peu':
        return 2
    if x == 'Oui, beaucoup':
        return 3

# %%
data_compet['Q39_cat']= data_compet['Q39'].apply(lambda x : competpolitique_Q39(x))
# Out:
# <ipython-input-362-a0c6aa9e7ded>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_compet['Q39_cat']= data_compet['Q39'].apply(lambda x : competpolitique_Q39(x))

# %%
data_compet['Q39_cat'].value_counts()
# Out:
# Q39_cat
# 2    883
# 1    504
# 3    408
# 0    374
# Name: count, dtype: int64

# %%
# définir une fonction pour recoder la variable 'Q40':
def competpolitique_Q40(x):
    
    if x == 'Jamais' or x ==  '#NULL!': 
        return 0
    if x == 'Moins souvent':
        return 1
    if x == 'Une à deux fois par semaine':
        return 2
    if x == 'Plusieurs fois par semaine':
        return 3
    if x == 'Tous les jours ou presque':
        return 4

# %%
data_compet['Q40_cat']= data_compet['Q40'].apply(lambda x : competpolitique_Q40(x))
# Out:
# <ipython-input-365-c13f44f8ea3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_compet['Q40_cat']= data_compet['Q40'].apply(lambda x : competpolitique_Q40(x))

# %%
data_compet['Q40_cat'].value_counts()
# Out:
# Q40_cat
# 4    597
# 1    458
# 3    450
# 2    363
# 0    301
# Name: count, dtype: int64

# %%
# définir une fonction pour recoder la variable 'Q41':
def competpolitique_Q41(x):
    if x == 'Vous ne votez pas' or x == '#NULL!':
        return 0
    if x == 'Vous votez rarement':
        return 1
    if x == 'Vous votez à certaines élections':
        return 2
    if x == 'Vous votez à la plupart des élections':
        return 3
    if x == 'Vous votez à toutes les élections':
        return 4

# %%
data_compet['Q41_cat']= data_compet['Q41'].apply(lambda x : competpolitique_Q41(x))
# Out:
# <ipython-input-368-acba282d70ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_compet['Q41_cat']= data_compet['Q41'].apply(lambda x : competpolitique_Q41(x))

# %%
data_compet['Q41_cat'].value_counts()
# Out:
# Q41_cat
# 4    1224
# 3     412
# 0     228
# 2     200
# 1     105
# Name: count, dtype: int64

# %%
data_compet[['Q39_cat', 'Q40_cat', 'Q41_cat']] = data_compet[['Q39_cat', 'Q40_cat', 'Q41_cat']].astype('category')
# Out:
# <ipython-input-370-3cf69b4a3d24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_compet[['Q39_cat', 'Q40_cat', 'Q41_cat']] = data_compet[['Q39_cat', 'Q40_cat', 'Q41_cat']].astype('category')

# %%
competpol= ['Q39_cat', 'Q40_cat', 'Q41_cat']

# %%
# Application de l'ACM
acm_competpol = prince.MCA(n_components = 2)

acm_competpol = acm_competpol.fit(data_compet[competpol])

ax = acm_competpol.plot(X=data_compet[competpol])
ax
# Out:
# alt.Chart(...)

# %%
competpol_s= acm_competpol.row_coordinates(data_compet)
competpol_s.rename(columns = {0:'Compoenent 0', 1 : 'Componenet 1'}, inplace = True)

competpol_score = pd.concat([data_compet, competpol_s], axis = 1)

# %%
competpol_score['Compoenent 0'].max()
# Out:
# 2.2148891420466748

# %%
competpol_score['Compoenent 0'].min()
# Out:
# -0.8107830615751421

# %%
competpol_score['Compoenent 0'].quantile([0, 0.20, 0.40, 0.60, 0.80, 1])
# Out:
# 0.0   -0.810783
# 0.2   -0.675934
# 0.4   -0.458983
# 0.6   -0.084662
# 0.8    0.603359
# 1.0    2.214889
# Name: Compoenent 0, dtype: float64

# %%
competpol_score.loc[competpol_score['Compoenent 0'] < -0.675934 ]
# Compétance très élevée
# Out:
#                 Q39                        Q40  \
# 1       Oui, un peu  Tous les jours ou presque
# 6       Oui, un peu  Tous les jours ou presque
# 9     Oui, beaucoup  Tous les jours ou presque
# 11      Oui, un peu  Tous les jours ou presque
# 12      Oui, un peu  Tous les jours ou presque
# ...             ...                        ...
# 2157  Oui, beaucoup  Tous les jours ou presque
# 2158  Oui, beaucoup  Tous les jours ou presque
# 2160  Oui, beaucoup  Tous les jours ou presque
# 2164  Oui, beaucoup  Tous les jours ou presque
# 2166    Oui, un peu  Tous les jours ou presque
#
#                                     Q41 Q39_cat Q40_cat Q41_cat  Compoenent 0  \
# 1     Vous votez à toutes les élections       2       4       4     -0.675934
# 6     Vous votez à toutes les élections       2       4       4     -0.675934
# 9     Vous votez à toutes les élections       3       4       4     -0.810783
# 11    Vous votez à toutes les élections       2       4       4     -0.675934
# ...

# %%
competpol_score.loc[competpol_score['Compoenent 0']> 0.603359]
# très faible
# Out:
#                    Q39            Q40                                Q41  \
# 3     Non, pas du tout         Jamais  Vous votez à toutes les élections
# 21              #NULL!         #NULL!                             #NULL!
# 23              #NULL!         #NULL!                             #NULL!
# 34    Non, pas du tout         Jamais                Vous votez rarement
# 35    Non, pas du tout         Jamais  Vous votez à toutes les élections
# ...                ...            ...                                ...
# 2155  Non, pas du tout         Jamais  Vous votez à toutes les élections
# 2159            #NULL!         #NULL!                             #NULL!
# 2161            #NULL!         #NULL!                             #NULL!
# 2167  Non, pas du tout  Moins souvent                Vous votez rarement
# 2168  Non, pas du tout  Moins souvent  Vous votez à toutes les élections
#
#      Q39_cat Q40_cat Q41_cat  Compoenent 0  Componenet 1
# ...

# %%
# définir une fonction pour faire 5 groupes de Compétence politique
def competancepol_5groupes(x):
    if x < -0.675934:
        return "Très élevé"
    if x > -0.675934 and x <= -0.458983:
        return "Elevé"
    if x > -0.458983 and x <= -0.084662:
        return "Moyen"
    if x > -0.084662 and x <= 0.603359:
        return "Faible"
    if x > 0.603359:
        return "Très faible"

# %%
competpol_score['competpol_score']= competpol_score['Compoenent 0'].apply(lambda x : competancepol_5groupes(x))

# %%
competpol_score['competpol_score'].value_counts()
# Out:
# competpol_score
# Très élevé     517
# Faible         458
# Très faible    425
# Elevé          411
# Moyen          358
# Name: count, dtype: int64

# %%
data2 = pd.concat([data1, competpol_score['competpol_score']], axis = 1)

# %%
data2['competpol_score'].isna().sum()
# Out:
# 0

# %%
#changer l'order des categories de la variable 'competpol_score'
data2['competpol_score'] = pd.Categorical(data2['competpol_score'], 
                            categories=['Très faible', 'Faible' ,'Moyen'
                                        ,'Elevé', 'Très élevé'], 
                            ordered=True)

# %%
# faire 3 groupes de Compétence politique
bin_labels_3 = ['Elevé', 'Moyen', 'Faible']
competpol_score['compet_pol_3'] = pd.qcut(competpol_score['Compoenent 0'], q=3, labels=bin_labels_3 )

# %%
competpol_score['compet_pol_3'].value_counts()
# Out:
# compet_pol_3
# Elevé     754
# Moyen     726
# Faible    689
# Name: count, dtype: int64

# %%
competpol_score['compet_pol_3'].value_counts()
# Out:
# compet_pol_3
# Elevé     754
# Moyen     726
# Faible    689
# Name: count, dtype: int64

# %%
data3 = pd.concat([data2, competpol_score['compet_pol_3']], axis = 1)

# %%
#changer l'order des categories de la variable 'compet_pol_3'
data3['compet_pol_3'] = pd.Categorical(data3['compet_pol_3'], 
                            categories=['Faible' ,'Moyen'
                                        ,'Elevé'], 
                            ordered=True)

# %%
data3['compet_pol_3'].value_counts()
# Out:
# compet_pol_3
# Elevé     754
# Moyen     726
# Faible    689
# Name: count, dtype: int64

# %%
# Variable 'Q42_A'
# Question: De laquelle des formations politiques suivantes vous sentez-vous le plus proche ou disons le moins éloigné ?
data3['Q42_A'].value_counts()
# Out:
# Q42_A
# Aucune formation politique                               646
# Le Rassemblement National                                338
# Renaissance (ex La République en Marche)                 164
# Le Parti Socialiste                                      156
# Les Républicains                                         151
# La France Insoumise                                      135
# Europe Ecologie Les Verts                                113
# #NULL!                                                   100
# Le Parti Communiste                                       67
# Reconquête (d&apos;Eric Zemmour)                          47
# Le MoDem                                                  42
# Une autre formation politique                             38
# Le NPA (Nouveau Parti Anticapitaliste)                    38
# Lutte Ouvrière                                            30
# Génération.s                                              27
# ...

# %%
# définir une fonction pour recoder la proximité politique:
def proxpol(x):
    if x == "Lutte Ouvrière" or x == "Le NPA (Nouveau Parti Anticapitaliste)" or x == "La France Insoumise" or x == "Le Parti Communiste":
        return "Far left"
    if x == "Génération.s" or x == "Le Parti Socialiste" or x == "Le Parti Radical de Gauche" :
        return "Left"
    if x == "Europe Ecologie Les Verts":
        return "Green party"
    if x == "Renaissance (ex La République en Marche)" or x == "Le MoDem" or x == "L’UDI (Union des Démocrates et Indépendants)":
        return "Center"
    if x == "Horizons (d&apos;Édouard Philippe)" or x == "Les Républicains":
        return "Right"
    if x == "Aucune formation politique" or x == "Une autre formation politique":
        return "No partisan proximity"
    if x == "#NULL!":
        return"Vous ne souhaitez pas répondre"
    return "Far right"

# %%
data3['Q42_A_cat']= data3['Q42_A'].apply(lambda x : proxpol(x))

# %%
data3['Q42_A_cat'].value_counts()
# Out:
# Q42_A_cat
# No partisan proximity             684
# Far right                         421
# Far left                          270
# Center                            220
# Left                              188
# Right                             173
# Green party                       113
# Vous ne souhaitez pas répondre    100
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q47_A_cat'
data3['Q42_A_cat'] = pd.Categorical(data3['Q42_A_cat'], 
                            categories=['Far right', 'Right' ,'Center'
                                        ,'Left', 'Far left'
                                       , 'Green party' , 'No partisan proximity'
                                        , 'Vous ne souhaitez pas répondre'], 
                            ordered=True)

# %%
# Variable 'Q43'
# Question: A quel point vous sentez-vous proche de ce parti ?
data3['Q43'].value_counts()
# Out:
# Q43
# Assez proche          880
# #NULL!                543
# Pas très proche       295
# Très proche           199
# Vous ne savez pas     151
# Pas du tout proche    101
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q43'
data3['Q43'] = pd.Categorical(data3['Q43'], 
                            categories=['Pas du tout proche', 'Pas très proche' ,'Assez proche'
                                        ,'Très proche', 'Vous ne savez pas'
                                       , '#NULL!'], 
                            ordered=True)

# %%
# Variable 'Q45_A'
# Question: Avez-vous confiance ou pas confiance dans : La justice
data3['Q45_A'].value_counts()
# Out:
# Q45_A
# Plutôt confiance                  715
# Plutôt pas confiance              602
# Pas du tout confiance             531
# Tout à fait confiance             112
# #NULL!                            104
# Vous ne savez pas                  57
# Vous ne souhaitez pas répondre     48
# Name: count, dtype: int64

# %%
# Variable 'Q45_B'
# Question: Avez-vous confiance ou pas confiance dans : Les médias
data3['Q45_B'].value_counts()
# Out:
# Q45_B
# Plutôt pas confiance              769
# Pas du tout confiance             609
# Plutôt confiance                  513
# #NULL!                            104
# Vous ne savez pas                  73
# Vous ne souhaitez pas répondre     52
# Tout à fait confiance              49
# Name: count, dtype: int64

# %%
# Variable 'Q45_C'
# Question: Avez-vous confiance ou pas confiance dans : La police
data3['Q45_C'].value_counts()
# Out:
# Q45_C
# Plutôt confiance                  1034
# Tout à fait confiance              405
# Plutôt pas confiance               319
# Pas du tout confiance              204
# #NULL!                             104
# Vous ne savez pas                   69
# Vous ne souhaitez pas répondre      34
# Name: count, dtype: int64

# %%
# Variable 'Q45_D'
# Question: Avez-vous confiance ou pas confiance dans : L’assemblée nationale
data3['Q45_D'].value_counts()
# Out:
# Q45_D
# Plutôt pas confiance              722
# Pas du tout confiance             613
# Plutôt confiance                  493
# Vous ne savez pas                 123
# #NULL!                            104
# Tout à fait confiance              68
# Vous ne souhaitez pas répondre     46
# Name: count, dtype: int64

# %%
# Variable 'Q45_E'
# Question: Avez-vous confiance ou pas confiance dans : Les maires
data3['Q45_E'].value_counts()
# Out:
# Q45_E
# Plutôt confiance                  1167
# Plutôt pas confiance               358
# Tout à fait confiance              255
# Pas du tout confiance              157
# #NULL!                             104
# Vous ne savez pas                   87
# Vous ne souhaitez pas répondre      41
# Name: count, dtype: int64

# %%
# Variable 'Q45_F'
# Question: Avez-vous confiance ou pas confiance dans : La science
data3['Q45_F'].value_counts()
# Out:
# Q45_F
# Plutôt confiance                  1245
# Tout à fait confiance              450
# Plutôt pas confiance               176
# #NULL!                             104
# Pas du tout confiance               91
# Vous ne savez pas                   75
# Vous ne souhaitez pas répondre      28
# Name: count, dtype: int64

# %%
# Variable 'Q45_G'
# Question: Avez-vous confiance ou pas confiance dans : Les grandes entreprises
data3['Q45_G'].value_counts()
# Out:
# Q45_G
# Plutôt confiance                  746
# Plutôt pas confiance              709
# Pas du tout confiance             370
# Vous ne savez pas                 119
# #NULL!                            104
# Tout à fait confiance              78
# Vous ne souhaitez pas répondre     43
# Name: count, dtype: int64

# %%
# Variable 'Q45_H'
# Question: Avez-vous confiance ou pas confiance dans : Les agences gouvernementales qui contrôlent les risques liés à la santé et à l'environnement
data3['Q45_H'].value_counts()
# Out:
# Q45_H
# Plutôt confiance                  806
# Plutôt pas confiance              557
# Pas du tout confiance             420
# Tout à fait confiance             116
# Vous ne savez pas                 115
# #NULL!                            104
# Vous ne souhaitez pas répondre     51
# Name: count, dtype: int64

# %%
# Variable 'Q45_I'
# Question: Avez-vous confiance ou pas confiance dans : Le gouvernement
data3['Q45_I'].value_counts()
# Out:
# Q45_I
# Pas du tout confiance             801
# Plutôt pas confiance              602
# Plutôt confiance                  473
# #NULL!                            104
# Vous ne savez pas                  76
# Tout à fait confiance              62
# Vous ne souhaitez pas répondre     51
# Name: count, dtype: int64

# %%
# Variable 'Q45_J'
# Question: Avez-vous confiance ou pas confiance dans : Les médecins
data3['Q45_J'].value_counts()
# Out:
# Q45_J
# Plutôt confiance                  1197
# Tout à fait confiance              554
# Plutôt pas confiance               172
# #NULL!                             104
# Pas du tout confiance               63
# Vous ne savez pas                   48
# Vous ne souhaitez pas répondre      31
# Name: count, dtype: int64

# %%
# Variable 'Q45_K'
# Question: Avez-vous confiance ou pas confiance dans : Les industriels du médicament
data3['Q45_K'].value_counts()
# Out:
# Q45_K
# Plutôt pas confiance              644
# Pas du tout confiance             617
# Plutôt confiance                  580
# Vous ne savez pas                 110
# #NULL!                            104
# Tout à fait confiance              68
# Vous ne souhaitez pas répondre     46
# Name: count, dtype: int64

# %%
# Variable 'Q45_L'
# Question: Avez-vous confiance ou pas confiance dans : Les partis politiques
data3['Q45_L'].value_counts()
# Out:
# Q45_L
# Pas du tout confiance             869
# Plutôt pas confiance              810
# Plutôt confiance                  187
# #NULL!                            104
# Vous ne savez pas                  99
# Vous ne souhaitez pas répondre     69
# Tout à fait confiance              31
# Name: count, dtype: int64

# %%
# Variable 'Q45_M'
# Question: Avez-vous confiance ou pas confiance dans : L’armée
data3['Q45_M'].value_counts()
# Out:
# Q45_M
# Plutôt confiance                  1046
# Tout à fait confiance              504
# Plutôt pas confiance               259
# Pas du tout confiance              133
# #NULL!                             104
# Vous ne savez pas                   88
# Vous ne souhaitez pas répondre      35
# Name: count, dtype: int64

# %%
# Variable 'Q45_N'
# Question: Avez-vous confiance ou pas confiance dans : Les scientifiques
data3['Q45_N'].value_counts()
# Out:
# Q45_N
# Plutôt confiance                  1204
# Tout à fait confiance              378
# Plutôt pas confiance               243
# Pas du tout confiance              112
# #NULL!                             104
# Vous ne savez pas                   84
# Vous ne souhaitez pas répondre      44
# Name: count, dtype: int64

# %%
ItemsQ45 = [ 'Q45_A', 'Q45_B', 'Q45_C', 'Q45_D', 'Q45_E', 'Q45_F', 'Q45_G', 'Q45_H', 'Q45_I', 'Q45_J', 'Q45_K', 'Q45_L', 'Q45_M', 'Q45_N']

# %%
for i in data3[ItemsQ45].columns:
    data3[i] = pd.Categorical(data3[i], 
                            categories=['Pas du tout confiance', 'Plutôt pas confiance'
                                        , 'Plutôt confiance'
                                        , 'Tout à fait confiance'
                                        , 'Vous ne savez pas'
                                       , 'Vous ne souhaitez pas répondre'
                                       , '#NULL!'] 
                                        , ordered=True)

# %%
# Variable 'Q46'
# Question: D'une manière générale, avez-vous l'impression que la science apporte à l'homme plus de bien que de mal, plus de mal que de bien ou à peu près autant de bien que de mal ?
data3['Q46'].value_counts()
# Out:
# Q46
# Plus de bien que de mal                 873
# À peu près autant de bien que de mal    865
# Plus de mal que de bien                 161
# Vous ne savez pas                       128
# #NULL!                                  105
# Vous ne voulez pas répondre              37
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q46'
data3['Q46'] = pd.Categorical(data3['Q46'], 
                        categories=["Plus de mal que de bien"
                                    , "À peu près autant de bien que de mal"
                                    , "Plus de bien que de mal"
                                    , "Vous ne savez pas"
                                    , "Vous ne voulez pas répondre" 
                                    , "#NULL!"], 
                            ordered=True)

# %%
# Variable 'Q47'
# Question: D’après vous, les connaissances actuelles permettent-elles de trancher le débat scientifique autour de l’efficacité de la chloroquine et de ses dérivés contre le COVID-19 ?
data3['Q47'].value_counts()
# Out:
# Q47
# Vous ne savez pas                                                                                            657
# Non, vous pensez que les connaissances sont encore insuffisantes                                             651
# Oui, et vous pensez que la chloroquine et ses dérivés ne sont pas un bon traitement contre le coronavirus    524
# Oui, et vous pensez que la chloroquine et ses dérivés sont un bon traitement contre le coronavirus           231
# #NULL!                                                                                                       106
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable'Q47'
data3['Q47'] = pd.Categorical(data3['Q47'], 
                            categories=['Non, vous pensez que les connaissances sont encore insuffisantes'
                                        , 'Oui, et vous pensez que la chloroquine et ses dérivés ne sont pas un bon traitement contre le coronavirus'
                                        , 'Oui, et vous pensez que la chloroquine et ses dérivés sont un bon traitement contre le coronavirus'
                                       , 'Vous ne savez pas'
                                       , '#NULL!'], 
                            ordered=True)

# %%
B = ['Ty_hes_vaccinale1', 'Q14',  'Q15_A', 'Q16_A', 'Q17_A', 'Q18_A', 'Q19_A', 'Q20', 'Q21', 'Q22', 'Q23', 'Q24'
    , 'Q25', 'Q26', 'Q27_A', 'Q27_B', 'Q27_C', 'Q27_D', 'Q28', 'Q29', 'Q30', 'Q31', 'Q36_A', 'Q36_B', 'Q36_C'
    , 'Q45_A', 'Q45_B', 'Q45_C', 'Q45_D', 'Q45_E', 'Q45_F', 'Q45_G', 'Q45_H', 'Q45_I', 'Q45_J', 'Q45_K', 'Q45_L', 'Q45_M', 'Q45_N'
    , 'Q46', 'Q47']

# %%
# Variable 'Q22'
# Question: Avez-vous entendu parler du VRS (Virus Respiratoire Syncytial) qui cause la bronchiolite chez le bébé ?
data3['Q22'].value_counts()
# Out:
# Q22
# Oui vaguement      861
# Pas du tout        482
# Oui tout à fait    435
# Pas vraiment       390
# #NULL!               1
# Name: count, dtype: int64

# %%
# Variable 'Q23'
# Question: Saviez-vous que le VRS (Virus Respiratoire Syncytial) cause des infections respiratoires chez l’adulte ?
data3['Q23'].value_counts()
# Out:
# Q23
# Pas du tout        891
# Pas vraiment       705
# Oui vaguement      408
# Oui tout à fait    164
# #NULL!               1
# Name: count, dtype: int64

# %%
ItemsQ22_23 = ['Q22', 'Q23']
for i in data3[ItemsQ22_23].columns:
    data3[i] = pd.Categorical(data3[i], 
                            categories=['Pas du tout', 'Pas vraiment'
                                        , 'Oui vaguement'
                                        , 'Oui tout à fait'
                                       , '#NULL!'] 
                                        , ordered=True)

# %%
# Variable 'Q24'
# Question: Etes-vous inquiets que l’un de vos proches ou vous-même attrapiez le VRS et contracte ces maladies ?
data3['Q24'].value_counts()
# Out:
# Q24
# Pas vraiment inquiet    1106
# Assez inquiet            581
# Pas du tout inquiet      327
# Très inquiet             152
# #NULL!                     3
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q24'
data3['Q24'] = pd.Categorical(data3['Q24'], 
                        categories=["Pas du tout inquiet"
                                    , "Pas vraiment inquiet"
                                    , "Assez inquiet"
                                    , "Très inquiet"
                                    , "#NULL!"], 
                            ordered=True)

# %%
# Variable 'Q25'
# Question: Pour protéger les bébés, un vaccin contre le VRS (virus respiratoire syncitial) sera prochainement disponible pour les femmes enceintes afin de transmettre des anticorps au bébé. Êtes-vous favorable à cette vaccination ?
data3['Q25'].value_counts()
# Out:
# Q25
# Plutôt favorable         981
# Très favorable           409
# Vous ne savez pas        383
# Plutôt pas favorable     226
# Pas du tout favorable    165
# #NULL!                     5
# Name: count, dtype: int64

# %%
# Variable 'Q26'
# Question: Pour protéger les personnes âgées et les personnes avec un système immunitaire faible des infections à VRS, un vaccin est sur le marché. S’il était recommandé en France, seriez-vous favorable à cette vaccination ?
data3['Q26'].value_counts()
# Out:
# Q26
# Plutôt favorable         965
# Vous ne savez pas        362
# Très favorable           351
# Plutôt pas favorable     285
# Pas du tout favorable    200
# #NULL!                     6
# Name: count, dtype: int64

# %%
Items25_26 = ['Q25', 'Q26']
for i in data3[Items25_26].columns:
    data3[i] = pd.Categorical(data3[i], 
                            categories=['Pas du tout favorable', 'Plutôt pas favorable' ,'Plutôt favorable'
                                        ,'Très favorable', 'Vous ne savez pas'
                                       , '#NULL!'] 
                                        , ordered=True)

# %%
# Variable 'Q27_A'
# Question: Avez-vous déjà fait le vaccin contre la grippe saisonnière ? Cette année 2023
data3['Q27_A'].value_counts()
# Out:
# Q27_A
# Non                  1459
# Oui                   665
# Vous ne savez pas      36
# #NULL!                  9
# Name: count, dtype: int64

# %%
# Variable 'Q27_B'
# Question: Avez-vous déjà fait le vaccin contre la grippe saisonnière ? En 2022
data3['Q27_B'].value_counts()
# Out:
# Q27_B
# Non                  1400
# Oui                   721
# Vous ne savez pas      39
# #NULL!                  9
# Name: count, dtype: int64

# %%
# Variable 'Q27_C'
# Question: Avez-vous déjà fait le vaccin contre la grippe saisonnière ? En 2021
data3['Q27_C'].value_counts()
# Out:
# Q27_C
# Non                  1397
# Oui                   713
# Vous ne savez pas      50
# #NULL!                  9
# Name: count, dtype: int64

# %%
# Variable 'Q27_D'
# Question: Avez-vous déjà fait le vaccin contre la grippe saisonnière ? Au moins une fois avant 2021
data3['Q27_D'].value_counts()
# Out:
# Q27_D
# Non                  1216
# Oui                   869
# Vous ne savez pas      75
# #NULL!                  9
# Name: count, dtype: int64

# %%
ItemsQ27 = ['Q27_A', 'Q27_B', 'Q27_C', 'Q27_D']
for i in data3[ItemsQ27].columns:
    data3[i] = pd.Categorical(data3[i], 
                            categories=['Non', 'Oui' , 'Vous ne savez pas'
                                       , '#NULL!'] 
                                        , ordered=True)

# %%
# Variable 'Q28'
# Question: Cette année 2023, avez-vous fait un rappel de vaccination contre la COVID-19 ?
data3['Q28'].value_counts()
# Out:
# Q28
# Non                  1637
# Oui                   497
# Vous ne savez pas      26
# #NULL!                  9
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q28'
data3['Q28'] = pd.Categorical(data3['Q28'], 
                        categories=['Non', 'Oui' , 'Vous ne savez pas'
                                    , '#NULL!'] 
                                     , ordered=True)

# %%
# Variable 'Q29'
# Question: A quel point êtes-vous favorable à l’administration d’un vaccin associant la grippe saisonnière et la COVID-19, dans une seule injection ?
data3['Q29'].value_counts()
# Out:
# Q29
# Pas du tout favorable    660
# Plutôt favorable         600
# Plutôt pas favorable     374
# Très favorable           304
# Vous ne savez pas        220
# #NULL!                    11
# Name: count, dtype: int64

# %%
#changer l'order des categories de la variable 'Q29'
data3['Q29'] = pd.Categorical(data3['Q29'], 
                            categories=['Pas du tout favorable', 'Plutôt pas favorable' ,'Plutôt favorable'
                                        ,'Très favorable', 'Vous ne savez pas'
                                        , '#NULL!'], 
                            ordered=True)

# %%
# Variable 'Q30'
# Question: Depuis le mois de septembre, la vaccination contre les papillomavirus humain (HPV) est organisée dans les collèges. Y êtes-vous favorable ?
data3['Q30'].value_counts()
# Out:
# Q30
# Plutôt favorable         937
# Tout à fait favorable    579
# Vous ne savez pas        229
# Plutôt pas favorable     229
# Pas du tout favorable    183
# #NULL!                    12
# Name: count, dtype: int64

# %%
# Variable 'Q31'
# Question: Plus généralement, êtes-vous favorable à ce que des campagnes de vaccination soient organisées dans les écoles, collèges et lycées ?
data3['Q31'].value_counts()
# Out:
# Q31
# Plutôt favorable         915
# Tout à fait favorable    675
# Plutôt pas favorable     219
# Pas du tout favorable    218
# Vous ne savez pas        129
# #NULL!                    13
# Name: count, dtype: int64

# %%
ItemsQ30_31 = [ 'Q30', 'Q31']
for i in data3[ItemsQ30_31].columns:
    data3[i] = pd.Categorical(data3[i], 
                            categories=['Pas du tout favorable', 'Plutôt pas favorable' ,'Plutôt favorable'
                                        ,'Tout à fait favorable', 'Vous ne savez pas'
                                        , '#NULL!'] 
                                        , ordered=True)

# %%
# fonction pour creer un tableau croisé multiple avec effectifs et pourcentages
def tableau_croise_final(
    data, var_dep, indeps):
    t_nombre = pyshs.tableau_croise_multiple(data,
                              var_dep,
                              indeps,
                              "poids_redresses_stand",               
                              contenu="absolu") 
    t_pourcentage = pyshs.tableau_croise_multiple(data,
                              var_dep,
                              indeps,
                              "poids_redresses_stand",                   
                              contenu="pourcentage" )
    t=pd.concat({n:pd.concat({"Effectif":t_nombre[n],"%":t_pourcentage[n]},axis=1)                     
        for n in t_nombre.columns if n != "Total" and n != "Distribution"},axis=1)
    
    for n in t_nombre.columns:
        if n == "Total":
            t["Total"] = t_nombre["Total"]

    t["Distribution"]= t_pourcentage["Distribution"]
    
    t = t.reset_index()
    
    t["Question"] = t["Variable"].apply(lambda x : x.split(' ')[0])
    
    t["Question"] = t["Question"].apply(lambda x : list({key: questions_variables[key] for key in [x]}.values())[0])
    
    t = t.set_index(['Question','Variable'])
    
    return t

# %%
Tableaux = {}
for i in B:
    tableau_i = tableau_croise_final(data3, i, list_indeps)
    Tableaux.update({i: tableau_i})

# %%
with pd.ExcelWriter(r"C:\Users\rana_\OneDrive\Bureau\inserm\travaux\ICOVAC2\transfer_8001089_files_a0cee13b\ICOVAC2_analyse\Tableaux_croisés_ICOVAC2.xlsx") as engine:
    for key, val in Tableaux.items():
        val.to_excel(engine, sheet_name=key)
# Out:
# <ipython-input-441-e0653e33597a>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   with pd.ExcelWriter(r"C:\Users\rana_\OneDrive\Bureau\inserm\travaux\ICOVAC2\transfer_8001089_files_a0cee13b\ICOVAC2_analyse\Tableaux_croisés_ICOVAC2.xlsx") as engine:

# %%
Tableau_croisé_Q45_A = tableau_croise_final(data3, 'Q45_A', list_indeps)
Tableau_croisé_Q45_A.to_excel(r"C:\Users\rana_\OneDrive\Bureau\inserm\travaux\ICOVAC2\transfer_8001089_files_a0cee13b\ICOVAC2_analyse\Tableau_croisé_Q45_A.xlsx")
# Out:
# <ipython-input-445-c0712eeb4f7a>:2: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   Tableau_croisé_Q45_A.to_excel(r"C:\Users\rana_\OneDrive\Bureau\inserm\travaux\ICOVAC2\transfer_8001089_files_a0cee13b\ICOVAC2_analyse\Tableau_croisé_Q45_A.xlsx")

# %%
Tableau_croisé_Q45_B = tableau_croise_final(data3, 'Q45_B', list_indeps)
Tableau_croisé_Q45_B.to_excel(r"C:\Users\rana_\OneDrive\Bureau\inserm\travaux\ICOVAC2\transfer_8001089_files_a0cee13b\ICOVAC2_analyse\Tableau_croisé_Q45_B.xlsx")
# Out:
# <ipython-input-446-e3fea0a73857>:2: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   Tableau_croisé_Q45_B.to_excel(r"C:\Users\rana_\OneDrive\Bureau\inserm\travaux\ICOVAC2\transfer_8001089_files_a0cee13b\ICOVAC2_analyse\Tableau_croisé_Q45_B.xlsx")
